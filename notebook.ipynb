# %%
# C:\Users\spmyl\Support Knowledge Copilot with Verified Citations

from pathlib import Path
import zipfile

zip_file = Path(r"C:\Users\spmyl\Support Knowledge Copilot with Verified Citations\support-knowledge-copilot-enterprise.zip")

extract_to = Path(r"C:\Users\spmyl\Support Knowledge Copilot with Verified Citations\support-knowledge-copilot")
extract_to.mkdir(parents=True, exist_ok=True)

with zipfile.ZipFile(zip_file, "r") as zip_ref:
    zip_ref.extractall(extract_to)

print("support-knowledge-copilot:")
print(extract_to)
# Out:
# support-knowledge-copilot:
# C:\Users\spmyl\Support Knowledge Copilot with Verified Citations\support-knowledge-copilot
